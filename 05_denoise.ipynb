# %%
from keras.callbacks import TensorBoard
from keras.datasets import mnist
import numpy as np
from matplotlib import pyplot as plt
import keras
from keras import layers

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/100
# 469/469 [==============================] - 8s 11ms/step - loss: 0.1640 - val_loss: 0.1174
# Epoch 2/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1139 - val_loss: 0.1088
# Epoch 3/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1081 - val_loss: 0.1050
# Epoch 4/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1051 - val_loss: 0.1030
# Epoch 5/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1031 - val_loss: 0.1012
# Epoch 6/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1017 - val_loss: 0.1001
# Epoch 7/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1005 - val_loss: 0.0990
# Epoch 8/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0996 - val_loss: 0.0983
# Epoch 9/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0990 - val_loss: 0.0978
# Epoch 10/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0983 - val_loss: 0.0973
# Epoch 11/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0979 - val_loss: 0.0971
# Epoch 12/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0975 - val_loss: 0.0965
# Epoch 13/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0971 - val_loss: 0.0961
# Epoch 14/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0969 - val_loss: 0.0961
# Epoch 15/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0966 - val_loss: 0.0960
# Epoch 16/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0965 - val_loss: 0.0957
# Epoch 17/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0962 - val_loss: 0.0954
# Epoch 18/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0960 - val_loss: 0.0955
# Epoch 19/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0959 - val_loss: 0.0952
# Epoch 20/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0958 - val_loss: 0.0953
# Epoch 21/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0957 - val_loss: 0.0950
# Epoch 22/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0955 - val_loss: 0.0949
# Epoch 23/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0954 - val_loss: 0.0948
# Epoch 24/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0953 - val_loss: 0.0949
# Epoch 25/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0952 - val_loss: 0.0954
# Epoch 26/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0951 - val_loss: 0.0946
# Epoch 27/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0951 - val_loss: 0.0949
# Epoch 28/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0950 - val_loss: 0.0945
# Epoch 29/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0949 - val_loss: 0.0943
# Epoch 30/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0948 - val_loss: 0.0947
# Epoch 31/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0948 - val_loss: 0.0947
# Epoch 32/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 33/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0942
# Epoch 34/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0946 - val_loss: 0.0944
# Epoch 35/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0946 - val_loss: 0.0941
# Epoch 36/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0945 - val_loss: 0.0940
# Epoch 37/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0944 - val_loss: 0.0942
# Epoch 38/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0944 - val_loss: 0.0941
# Epoch 39/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0944 - val_loss: 0.0942
# Epoch 40/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0944 - val_loss: 0.0945
# Epoch 41/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0943 - val_loss: 0.0943
# Epoch 42/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0943 - val_loss: 0.0941
# Epoch 43/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0942 - val_loss: 0.0938
# Epoch 44/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0942 - val_loss: 0.0937
# Epoch 45/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0942 - val_loss: 0.0938
# Epoch 46/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0942 - val_loss: 0.0938
# Epoch 47/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0941 - val_loss: 0.0937
# Epoch 48/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0941 - val_loss: 0.0937
# Epoch 49/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 50/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0940 - val_loss: 0.0936
# Epoch 51/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0940 - val_loss: 0.0939
# Epoch 52/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0940 - val_loss: 0.0937
# Epoch 53/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0940 - val_loss: 0.0941
# Epoch 54/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0940 - val_loss: 0.0936
# Epoch 55/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 56/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 57/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 58/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0938 - val_loss: 0.0941
# Epoch 59/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0945
# Epoch 60/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 61/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0934
# Epoch 62/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0938 - val_loss: 0.0934
# Epoch 63/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0943
# Epoch 64/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 65/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 66/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0937 - val_loss: 0.0938
# Epoch 67/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0937 - val_loss: 0.0933
# Epoch 68/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0937 - val_loss: 0.0940
# Epoch 69/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0937
# Epoch 70/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 71/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 72/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 73/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 74/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0932
# Epoch 75/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0937
# Epoch 76/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 77/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 78/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 79/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 80/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 81/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 82/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 83/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 84/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 85/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 86/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 87/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 88/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 89/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0935
# Epoch 90/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 91/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 92/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 93/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 94/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 95/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 96/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 97/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 98/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 99/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 100/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0933 - val_loss: 0.0931

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step
