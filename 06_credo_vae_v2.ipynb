# %%
from matplotlib import pyplot as plt
import keras
from keras import layers
from keras.datasets import mnist
import numpy as np
import pickle
from keras import backend as K


DOTS_DST = 'cache/dots_v2.pickle'
TRACKS_DST = 'cache/tracks_v2.pickle'
WORMS_DST = 'cache/worms_v2.pickle'
ARTIFACTS_DST = 'cache/artifacts_v2.pickle'

original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2
batch_size = 32

def load_from_file(fn):
    return pickle.loads(open(fn, "rb").read())

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
def load_credo():
    w, h = 60, 60
    w1 = int((w-28)/2)
    h1 = int((h-28)/2)

    dots, a_dots = load_from_file(DOTS_DST)
    tracks, a_tracks = load_from_file(TRACKS_DST)
    worms, a_worms = load_from_file(WORMS_DST)

    y_dots = np.ones(dots.shape[0])
    y_tracks = np.ones(tracks.shape[0]) * 2
    y_worms = np.ones(worms.shape[0]) * 3

    y_a_dots = np.ones(a_dots.shape[0])
    y_a_tracks = np.ones(a_tracks.shape[0]) * 2
    y_a_worms = np.ones(a_worms.shape[0]) * 3

    x_test = np.vstack([tracks[:,w1:w1+28,h1:h1+28]])
    x_train = np.vstack([a_tracks[:,w1:w1+28,h1:h1+28]])

    y_test = np.hstack([y_tracks])
    y_train = np.hstack([y_a_tracks])
    return (x_train, y_train), (x_test, y_test)

(x_train, y_train), (x_test, y_test) = load_credo()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=50,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 19.9248 - val_loss: 0.8042
# Epoch 2/50
# 2108/2108 [==============================] - 15s 7ms/step - loss: 0.4972 - val_loss: 0.3081
# Epoch 3/50
# 2108/2108 [==============================] - 15s 7ms/step - loss: 0.2461 - val_loss: 0.2006
# Epoch 4/50
# 2108/2108 [==============================] - 14s 6ms/step - loss: 0.1839 - val_loss: 0.1697
# Epoch 5/50
# 2108/2108 [==============================] - 14s 7ms/step - loss: 0.1703 - val_loss: 0.1668
# Epoch 6/50
# 2108/2108 [==============================] - 14s 7ms/step - loss: 0.1689 - val_loss: 0.1664
# Epoch 7/50
# 2108/2108 [==============================] - 15s 7ms/step - loss: 0.1687 - val_loss: 0.1663
# Epoch 8/50
# 2108/2108 [==============================] - 16s 7ms/step - loss: 0.1686 - val_loss: 0.1663
# Epoch 9/50
# 2108/2108 [==============================] - 16s 7ms/step - loss: 0.1686 - val_loss: 0.1662
# Epoch 10/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1686 - val_loss: 0.1662
# Epoch 11/50
# 2108/2108 [==============================] - 16s 7ms/step - loss: 0.1686 - val_loss: 0.1660
# Epoch 12/50
# 2108/2108 [==============================] - 16s 7ms/step - loss: 0.1686 - val_loss: 0.1662
# Epoch 13/50
# 2108/2108 [==============================] - 16s 7ms/step - loss: 0.1686 - val_loss: 0.1660
# Epoch 14/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1686 - val_loss: 0.1663
# Epoch 15/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1686 - val_loss: 0.1661
# Epoch 16/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1685 - val_loss: 0.1658
# Epoch 17/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1685 - val_loss: 0.1662
# Epoch 18/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1685 - val_loss: 0.1664
# Epoch 19/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1660
# Epoch 20/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1684 - val_loss: 0.1662
# Epoch 21/50
# 2108/2108 [==============================] - 15s 7ms/step - loss: 0.1684 - val_loss: 0.1661
# Epoch 22/50
# 2108/2108 [==============================] - 15s 7ms/step - loss: 0.1684 - val_loss: 0.1660
# Epoch 23/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1684 - val_loss: 0.1660
# Epoch 24/50
# 2108/2108 [==============================] - 16s 7ms/step - loss: 0.1684 - val_loss: 0.1660
# Epoch 25/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1662
# Epoch 26/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1665
# Epoch 27/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1662
# Epoch 28/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1661
# Epoch 29/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1683 - val_loss: 0.1660
# Epoch 30/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1661
# Epoch 31/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1661
# Epoch 32/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1657
# Epoch 33/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1664
# Epoch 34/50
# 2108/2108 [==============================] - 18s 9ms/step - loss: 0.1684 - val_loss: 0.1663
# Epoch 35/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1662
# Epoch 36/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1684 - val_loss: 0.1661
# Epoch 37/50
# 2108/2108 [==============================] - 17s 8ms/step - loss: 0.1683 - val_loss: 0.1663
# Epoch 38/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1684 - val_loss: 0.1658
# Epoch 39/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1684 - val_loss: 0.1663
# Epoch 40/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1683 - val_loss: 0.1665
# Epoch 41/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1683 - val_loss: 0.1661
# Epoch 42/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1683 - val_loss: 0.1656
# Epoch 43/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1684 - val_loss: 0.1662
# Epoch 44/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1683 - val_loss: 0.1658
# Epoch 45/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1684 - val_loss: 0.1661
# Epoch 46/50
# 2108/2108 [==============================] - 16s 8ms/step - loss: 0.1684 - val_loss: 0.1661
# Epoch 47/50
# 2108/2108 [==============================] - 14s 7ms/step - loss: 0.1684 - val_loss: 0.1659
# Epoch 48/50
# 2108/2108 [==============================] - 16s 7ms/step - loss: 0.1684 - val_loss: 0.1660
# Epoch 49/50
# 2108/2108 [==============================] - 14s 7ms/step - loss: 0.1684 - val_loss: 0.1658
# Epoch 50/50
# 2108/2108 [==============================] - 13s 6ms/step - loss: 0.1684 - val_loss: 0.1658

# %%
x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[-1][:, 0], x_test_encoded[-1][:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# 96/96 [==============================] - 0s 1ms/step

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
