# %%
import numpy as np
from credo import load_from_file
from scipy.cluster.hierarchy import dendrogram


def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
distance = load_from_file('cache/dots_match.dat')
clustering = load_from_file('cache/dots_clusters.dat')

plot_dendrogram(clustering, truncate_mode="level", p=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 4
#       1 distance = load_from_file('cache/dots_match.dat')
#       2 clustering = load_from_file('cache/dots_clusters.dat')
# ----> 4 plot_dendrogram(clustering, truncate_mode="level", p=30)
#
# Cell In [5], line 26, in plot_dendrogram(model, **kwargs)
#      21 linkage_matrix = np.column_stack(
#      22     [model.children_, model.distances_, counts]
#      23 ).astype(float)
#      25 # Plot the corresponding dendrogram
# ---> 26 dendrogram(linkage_matrix, **kwargs)
#
# ...

# %%
distance = load_from_file('cache/tracks_match.dat')
clustering = load_from_file('cache/tracks_clusters.dat')

plot_dendrogram(clustering, truncate_mode="level", p=30)

# %%
distance = load_from_file('cache/worms_match.dat')
clustering = load_from_file('cache/worms_clusters.dat')

plot_dendrogram(clustering, truncate_mode="level", p=30)

# %%
distance = load_from_file('cache/all_match.dat')
clustering = load_from_file('cache/all_clusters.dat')

plot_dendrogram(clustering, truncate_mode="level", p=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [9], line 4
#       1 distance = load_from_file('cache/all_match.dat')
#       2 clustering = load_from_file('cache/all_clusters.dat')
# ----> 4 plot_dendrogram(clustering, truncate_mode="level", p=30)
#
# Cell In [5], line 26, in plot_dendrogram(model, **kwargs)
#      21 linkage_matrix = np.column_stack(
#      22     [model.children_, model.distances_, counts]
#      23 ).astype(float)
#      25 # Plot the corresponding dendrogram
# ---> 26 dendrogram(linkage_matrix, **kwargs)
#
# ...

# %%
distance = load_from_file('cache/tracks_hough_match.dat')
clustering = load_from_file('cache/tracks_hough_clusters.dat')

plot_dendrogram(clustering, truncate_mode="level", p=30)
