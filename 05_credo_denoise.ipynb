# %%
from keras.callbacks import TensorBoard
from credo import load_data
import numpy as np
from matplotlib import pyplot as plt
import keras
from keras import layers

(x_train, _), (x_test, _) = load_data(use_worms=True)

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/100
# 86/86 [==============================] - 3s 13ms/step - loss: 0.1414 - val_loss: 0.0575
# Epoch 2/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0523 - val_loss: 0.0485
# Epoch 3/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0477 - val_loss: 0.0463
# Epoch 4/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0456 - val_loss: 0.0444
# Epoch 5/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0442 - val_loss: 0.0431
# Epoch 6/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0433 - val_loss: 0.0427
# Epoch 7/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0427 - val_loss: 0.0420
# Epoch 8/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0422 - val_loss: 0.0421
# Epoch 9/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0419 - val_loss: 0.0412
# Epoch 10/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0415 - val_loss: 0.0412
# Epoch 11/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0413 - val_loss: 0.0407
# Epoch 12/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0410 - val_loss: 0.0404
# Epoch 13/100
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0408 - val_loss: 0.0403
# Epoch 14/100
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0407 - val_loss: 0.0401
# Epoch 15/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0405 - val_loss: 0.0400
# Epoch 16/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0404 - val_loss: 0.0403
# Epoch 17/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 18/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 19/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0401 - val_loss: 0.0396
# Epoch 20/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0400 - val_loss: 0.0401
# Epoch 21/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0399 - val_loss: 0.0395
# Epoch 22/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0398 - val_loss: 0.0393
# Epoch 23/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0397 - val_loss: 0.0399
# Epoch 24/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0396 - val_loss: 0.0392
# Epoch 25/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0395 - val_loss: 0.0391
# Epoch 26/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0395 - val_loss: 0.0391
# Epoch 27/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0393 - val_loss: 0.0390
# Epoch 28/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0392 - val_loss: 0.0390
# Epoch 29/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0392 - val_loss: 0.0388
# Epoch 30/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0392 - val_loss: 0.0388
# Epoch 31/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0392 - val_loss: 0.0390
# Epoch 32/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0390 - val_loss: 0.0388
# Epoch 33/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0390 - val_loss: 0.0388
# Epoch 34/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0389 - val_loss: 0.0391
# Epoch 35/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0389 - val_loss: 0.0386
# Epoch 36/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0388 - val_loss: 0.0386
# Epoch 37/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0388 - val_loss: 0.0387
# Epoch 38/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0387 - val_loss: 0.0385
# Epoch 39/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0386 - val_loss: 0.0385
# Epoch 40/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0387 - val_loss: 0.0385
# Epoch 41/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0385 - val_loss: 0.0385
# Epoch 42/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0385 - val_loss: 0.0385
# Epoch 43/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0385 - val_loss: 0.0384
# Epoch 44/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0384 - val_loss: 0.0384
# Epoch 45/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0384 - val_loss: 0.0385
# Epoch 46/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0384 - val_loss: 0.0384
# Epoch 47/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0383 - val_loss: 0.0384
# Epoch 48/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0382 - val_loss: 0.0384
# Epoch 49/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0382 - val_loss: 0.0389
# Epoch 50/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0382 - val_loss: 0.0384
# Epoch 51/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0382 - val_loss: 0.0383
# Epoch 52/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0381 - val_loss: 0.0383
# Epoch 53/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0381 - val_loss: 0.0381
# Epoch 54/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0380 - val_loss: 0.0384
# Epoch 55/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0380 - val_loss: 0.0382
# Epoch 56/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0380 - val_loss: 0.0382
# Epoch 57/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0379 - val_loss: 0.0381
# Epoch 58/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0379 - val_loss: 0.0382
# Epoch 59/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0378 - val_loss: 0.0384
# Epoch 60/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0378 - val_loss: 0.0382
# Epoch 61/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0378 - val_loss: 0.0381
# Epoch 62/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0377 - val_loss: 0.0382
# Epoch 63/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0377 - val_loss: 0.0382
# Epoch 64/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0376 - val_loss: 0.0384
# Epoch 65/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0377 - val_loss: 0.0384
# Epoch 66/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0377 - val_loss: 0.0383
# Epoch 67/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0376 - val_loss: 0.0383
# Epoch 68/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0376 - val_loss: 0.0382
# Epoch 69/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0375 - val_loss: 0.0386
# Epoch 70/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0375 - val_loss: 0.0382
# Epoch 71/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0375 - val_loss: 0.0380
# Epoch 72/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0375 - val_loss: 0.0380
# Epoch 73/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0374 - val_loss: 0.0381
# Epoch 74/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0374 - val_loss: 0.0382
# Epoch 75/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0374 - val_loss: 0.0381
# Epoch 76/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0374 - val_loss: 0.0381
# Epoch 77/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0373 - val_loss: 0.0384
# Epoch 78/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0373 - val_loss: 0.0382
# Epoch 79/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0372 - val_loss: 0.0382
# Epoch 80/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0372 - val_loss: 0.0383
# Epoch 81/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0373 - val_loss: 0.0382
# Epoch 82/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0372 - val_loss: 0.0381
# Epoch 83/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0372 - val_loss: 0.0385
# Epoch 84/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0372 - val_loss: 0.0383
# Epoch 85/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0371 - val_loss: 0.0382
# Epoch 86/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0371 - val_loss: 0.0383
# Epoch 87/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0371 - val_loss: 0.0381
# Epoch 88/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0370 - val_loss: 0.0383
# Epoch 89/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0370 - val_loss: 0.0383
# Epoch 90/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0370 - val_loss: 0.0385
# Epoch 91/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0370 - val_loss: 0.0387
# Epoch 92/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0370 - val_loss: 0.0383
# Epoch 93/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0369 - val_loss: 0.0382
# Epoch 94/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0370 - val_loss: 0.0383
# Epoch 95/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0369 - val_loss: 0.0386
# Epoch 96/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0368 - val_loss: 0.0385
# Epoch 97/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0368 - val_loss: 0.0385
# Epoch 98/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0368 - val_loss: 0.0384
# Epoch 99/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0368 - val_loss: 0.0385
# Epoch 100/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0367 - val_loss: 0.0384

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 16/16 [==============================] - 0s 4ms/step
